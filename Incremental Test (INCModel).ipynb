# %%
import torch
from torch import nn
from torchmetrics import Accuracy, F1Score, Precision, AUROC
import pytorch_lightning as pl
import torchsummary

from torchmetrics import Accuracy, F1Score, Precision, AUROC, ConfusionMatrix
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
import pandas as pd
from avalanche.benchmarks import benchmark_with_validation_stream, nc_benchmark
from torch.utils.data import Dataset

# %%
class TorchDataset(Dataset):

    def __init__(self,filePath):

        device = 'cuda' if torch.cuda.is_available() else 'cpu'
        # Read CSV
        data = pd.read_csv(filePath)

        self.X = data.iloc[:,:-1].values
        self.targets = data.iloc[:, -1].values

        # Feature Scale if you want


        # Convert to Torch Tensors
        self.X = torch.tensor(self.X, dtype=torch.float32)
        self.targets = torch.tensor(self.targets, dtype=torch.int)

    def __len__(self):
        return len(self.targets)

    def __getitem__(self, item):

        return self.X[item], self.targets[item]


def prep_benchmark(train_loc, test_loc):
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(device)

    hdata_train = TorchDataset(train_loc)
    hdata_test = TorchDataset(test_loc)

    return benchmark_with_validation_stream(nc_benchmark(train_dataset=hdata_train, test_dataset=hdata_test
                                 , shuffle=True, seed=1234, task_labels=False, per_exp_classes={0:7},n_experiences=7))

# %%
from avalanche.models import PNN
from avalanche.models.dynamic_modules import (
    MultiTaskModule,
    MultiHeadClassifier, IncrementalClassifier, DynamicModule,
)


class Simple1DCNN(nn.Module):
    """
    Convolutional Neural Network

    **Example**::

         from avalanche.models import SimpleCNN
         n_classes = 10 # e.g. MNIST
         model = SimpleCNN(num_classes=n_classes)
         print(model) # View model details
    """

    def __init__(self, num_classes=10):
        super(Simple1DCNN, self).__init__()

        self.features = nn.Sequential(
        nn.Conv1d(in_channels=1, out_channels=32, padding='same',  kernel_size=3,),
        nn.MaxPool1d(4),
        nn.Conv1d(in_channels=32, out_channels=32, padding='same',  kernel_size=3),
        nn.MaxPool1d(4),
        nn.Conv1d(in_channels=32, out_channels=16, padding='same',  kernel_size=3),
        nn.MaxPool1d(4),
        nn.Conv1d(in_channels=16, out_channels=16, padding='same',  kernel_size=3),
        nn.MaxPool1d(4),
        )
        self.classifier = nn.Sequential(nn.Linear(256, num_classes))


# IN MTS it doesn't even use this foward
    def forward(self, x):
        x = x.unsqueeze(dim=1)
        x = self.features(x)
        x = x.view(x.size(0), -1)
        # x = self.classifier(x, task_labels)#TODO: previously

        x = self.fc1(x)
        x = torch.relu(x)
        x = self.fc2(x)
        x = torch.relu(x)
        x = self.fc3(x)
        x = torch.log_softmax(x, dim=1)
        return x



class MTSimple1DCNN(Simple1DCNN, DynamicModule):
    """
    Convolutional Neural Network
    with multi-head classifier
    """

    def __init__(self):
        super().__init__()
        self.classifier = IncrementalClassifier(in_features=256, initial_out_features=1,masking=False)

# CHECK: `initial_out_features`. is the problem her it has to be consistant, so we are not going to use a multitask module
    def forward(self, x, ):
        x = x.unsqueeze(dim=1)
        x = self.features(x)
        x = x.view(x.size(0), -1)
        print(f'after squeeze : {x.shape}')
        x = self.classifier(x,)
        return x

# %%
# from avalanche.models import DynamicModule
# from avalanche.benchmarks import CLExperience
#
#
# class Incremental1DClassifier(DynamicModule):
#     """
#     Output layer that incrementally adds units whenever new classes are
#     encountered.
#
#     Typically used in class-incremental benchmarks where the number of
#     classes grows over time.
#     """
#
#     def __init__(
#         self,
#         in_features,
#         initial_out_features=2,
#         masking=True,
#         mask_value=-1000,
#     ):
#         """
#         :param in_features: number of input features.
#         :param initial_out_features: initial number of classes (can be
#             dynamically expanded).
#         :param masking: whether unused units should be masked (default=True).
#         :param mask_value: the value used for masked units (default=-1000).
#         """
#         super().__init__()
#         self.masking = masking
#         self.mask_value = mask_value
#
#         self.classifier = torch.nn.Linear(in_features, initial_out_features)
#         au_init = torch.zeros(initial_out_features, dtype=torch.bool)
#         self.register_buffer("active_units", au_init)
#
#
#     @torch.no_grad()
#     def adaptation(self, experience: CLExperience):
#         """If `dataset` contains unseen classes the classifier is expanded.
#
#         :param experience: data from the current experience.
#         :return:
#         """
#         in_features = self.classifier.in_features
#         old_nclasses = self.classifier.out_features
#         curr_classes = experience.classes_in_this_experience
#         new_nclasses = max(self.classifier.out_features, max(curr_classes) + 1)
#
#         # update active_units mask
#         if self.masking:
#             if old_nclasses != new_nclasses:  # expand active_units mask
#                 old_act_units = self.active_units
#                 self.active_units = torch.zeros(new_nclasses, dtype=torch.bool)
#                 self.active_units[: old_act_units.shape[0]] = old_act_units
#             # update with new active classes
#             if self.training:
#                 self.active_units[curr_classes] = 1
#
#         # update classifier weights
#         if old_nclasses == new_nclasses:
#             return
#         old_w, old_b = self.classifier.weight, self.classifier.bias
#         self.classifier = torch.nn.Linear(in_features, new_nclasses)
#         self.classifier.weight[:old_nclasses] = old_w
#         self.classifier.bias[:old_nclasses] = old_b
#
#     def forward(self, x, **kwargs):
#         """compute the output given the input `x`. This module does not use
#         the task label.
#
#         :param x:
#         :return:
#         """
#         out = self.classifier(x)
#         if self.masking:
#             out[..., torch.logical_not(self.active_units)] = self.mask_value
#         return out

# %%
class CNN1D(pl.LightningModule):
    def __init__(self, input_shape):

        self.save_hyperparameters()# to Save Hyperparameters
        super(CNN1D, self).__init__()
        self.conv1D_1 = nn.Conv1d(in_channels=1, out_channels=32, padding='same',  kernel_size=3,)
        self.maxPool1D_1 = nn.MaxPool1d(4)
        self.conv1D_2 = nn.Conv1d(in_channels=32, out_channels=32, padding='same',  kernel_size=3)
        self.maxPool1D_2 = nn.MaxPool1d(4)
        self.conv1D_3 = nn.Conv1d(in_channels=32, out_channels=16, padding='same',  kernel_size=3)
        self.maxPool1D_3 = nn.MaxPool1d(4)
        self.conv1D_4 = nn.Conv1d(in_channels=16, out_channels=16, padding='same',  kernel_size=3)
        self.maxPool1D_4 = nn.MaxPool1d(4)



        self.fc1 = nn.Linear(256, 300)
        self.fc2 = nn.Linear(300, 128)
        self.fc3 = nn.Linear(128, 31)

        self.train_accuracy = Accuracy(task='multiclass', num_classes=31)
        self.train_f1 = F1Score(task='multiclass', num_classes=31)
        self.train_precisn = Precision(task='multiclass', num_classes=31)
        self.train_rocAUC = AUROC(task='multiclass', num_classes=31)

        self.val_accuracy = Accuracy(task='multiclass', num_classes=31)
        self.val_f1 = F1Score(task='multiclass', num_classes=31)
        self.val_precisn = Precision(task='multiclass', num_classes=31)
        self.val_rocAUC = AUROC(task='multiclass', num_classes=31)

        self.test_accuracy = Accuracy(task='multiclass', num_classes=31)
        self.test_f1 = F1Score(task='multiclass', num_classes=31)
        self.test_precisn = Precision(task='multiclass', num_classes=31)
        self.test_rocAUC = AUROC(task='multiclass', num_classes=31)
        self.confusion_matrix = ConfusionMatrix(task="multiclass", num_classes=31)


    def forward(self, x):
        # block 1
        x = x.unsqueeze(dim=1)
        x = self.conv1D_1(x)
        x = torch.relu(x)
        x= self.maxPool1D_1(x)


        # block 2
        x = self.conv1D_2(x)
        x = torch.relu(x)
        x= self.maxPool1D_2(x)

        # block 3
        x = self.conv1D_3(x)
        x = torch.relu(x)
        x= self.maxPool1D_3(x)

        # block 4
        x = self.conv1D_4(x)
        x = torch.relu(x)
        x= self.maxPool1D_4(x)

        # Flatten

        x = x.reshape(x.shape[0], -1)

        x = self.fc1(x)
        x = torch.relu(x)
        x = self.fc2(x)
        x = torch.relu(x)
        x = self.fc3(x)
        x = torch.log_softmax(x, dim=1)
        return x

    def training_step(self, batch, batch_idx):
        x, y = batch
        x = x.unsqueeze(dim=1)

        y_pred = self.forward(x)
        loss = nn.CrossEntropyLoss()(y_pred,y.long())
        self.log('train_loss', loss, on_epoch=True, on_step=True,prog_bar=True)
        self.log('train_acc_step', self.train_accuracy(y_pred, y.long(), ), on_epoch=True, on_step=True,prog_bar=False)
        self.log('train_f1_step', self.train_f1(y_pred, y.long(), ), on_epoch=True, on_step=True,prog_bar=False)
        self.log('train_precision_step', self.train_precisn(y_pred, y.long(), ), on_epoch=True, on_step=True,)
        self.log('train_auc_step', self.train_rocAUC(y_pred, y.long(), ), on_epoch=True, on_step=True,prog_bar=False )
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        x = x.unsqueeze(dim=1)
        y_pred = self.forward(x)
        loss = nn.CrossEntropyLoss()(y_pred,y.long())
        self.log('validation_loss', loss)
        self.log('val_loss', loss, on_epoch=True)
        self.log('val_acc', self.val_accuracy(y_pred, y.long(), ),on_epoch=True, prog_bar=True)
        self.log('val_f1', self.val_f1(y_pred, y.long(), ),on_epoch=True, prog_bar=True)
        self.log('val_precision', self.val_precisn(y_pred, y.long(), ),on_epoch=True, prog_bar=True)
        self.log('val_auc', self.val_rocAUC(y_pred, y.long(), ),on_epoch=True, prog_bar=True)
        return loss

    def test_step(self, batch, batch_idx):
        # this is the test loop
        x, y = batch
        x = x.unsqueeze(dim=1)
        # img = x.view(-1,3,IMG_SIZE,IMG_SIZE)
        y_pred = self.forward(x)
        loss = nn.CrossEntropyLoss()(y_pred,y.long())
        # self.log('test_loss', loss)
        # self.log('test_loss', loss, on_epoch=True)
        self.log('test_acc', self.test_accuracy(y_pred, y.long(), ),)
        self.log('test_f1', self.test_f1(y_pred, y.long(), ),)
        self.log('test_precision', self.test_precisn(y_pred, y.long(), ),)
        self.log('test_auc', self.test_rocAUC(y_pred, y.long(), ),)
        self.confusion_matrix(y_pred, y.long())
        print(self.confusion_matrix)
        # self.logger.experiment.add_confusion_matrix('confusion_matrix', self.confusion_matrix)
        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=1e-3)
        return optimizer

# model = CNN1D(input_shape=4097,)

# %%
from avalanche.models import MTSimpleMLP, MTSimpleCNN
from torch.nn import CrossEntropyLoss
from avalanche.training import Naive, EWC
from avalanche.evaluation.metrics import accuracy_metrics, loss_metrics, timing_metrics, forgetting_metrics, \
    cpu_usage_metrics, disk_usage_metrics
from avalanche.training.plugins import EvaluationPlugin
from avalanche.logging import TensorboardLogger, TextLogger, InteractiveLogger
import avalanche as avl




benchmark = prep_benchmark(train_loc='./DATA/TRAIN_DATA.csv', test_loc='./DATA/TEST_DATA.csv')


# log to Tensorboard
tb_logger = TensorboardLogger()

# log to text file
text_logger = TextLogger(open('log.txt', 'a'))

# print to stdout
interactive_logger = InteractiveLogger()

eval_plugin = EvaluationPlugin(
    accuracy_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    loss_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    timing_metrics(epoch=True, epoch_running=True),
    forgetting_metrics(experience=True, stream=True),
    cpu_usage_metrics(experience=True),
    # confusion_matrix_metrics(num_classes=benchmark['inc_bench'].n_classes, save_image=False,
    #                          stream=True),
    disk_usage_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    loggers=[interactive_logger, text_logger, tb_logger]
)

# CREATE THE STRATEGY INSTANCE (EWC)
# model2 = avl.models.PNN(in_features=4096,hidden_features_per_column=1000,num_layers=7,)
# model3 =  MTSimpleCNN()
model4 = MTSimple1DCNN()
# TODO: 4096 is too much i might need to pass thought the cnn first and then pass it to the pnn
cl_strategy = EWC(
    model4, torch.optim.Adam(model4.parameters(), lr=0.001,),
    CrossEntropyLoss(), train_mb_size=500, train_epochs=10, eval_mb_size=100,
    evaluator=eval_plugin,ewc_lambda=0.4)

# TRAINING LOOP
print('Starting experiment...')
results = []
model_incs = []
classes_exp= []
for experience in benchmark.train_stream:
    print("Start of experience: ", experience.current_experience)
    print("Current Classes: ", experience.classes_in_this_experience)
    model_incs.append(model4.classifier)
    classes_exp.append(experience.classes_in_this_experience)
    # train returns a dictionary which contains all the metric values
    res = cl_strategy.train(experience)
    print('Training completed')

    print('Computing accuracy on the whole test set')
    # test also returns a dictionary which contains all the metric values
    results.append(cl_strategy.eval(benchmark.test_stream))
# Out:
# cpu
# Starting experiment...
# Start of experience:  0
# Current Classes:  [8, 13, 12, 5]
# -- >> Start of training phase << --
# 0it [00:00, ?it/s]after squeeze : torch.Size([67, 256])
# 100%|██████████| 1/1 [00:00<00:00,  5.91it/s]
# Epoch 0 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328767.3535
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328767.3535
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.6528
# 	Loss_MB/train_phase/train_stream/Task000 = 2.6528
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.1495
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.1495
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([67, 256])
# 100%|██████████| 1/1 [00:00<00:00, 13.79it/s]
# Epoch 1 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328768.4561
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328768.4561
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.5005
# 	Loss_MB/train_phase/train_stream/Task000 = 2.5005
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0637
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0637
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([67, 256])
# 100%|██████████| 1/1 [00:00<00:00, 13.64it/s]
# Epoch 2 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328769.5664
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328769.5664
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.3634
# 	Loss_MB/train_phase/train_stream/Task000 = 2.3634
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0603
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0603
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3731
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.3731
# 0it [00:00, ?it/s]after squeeze : torch.Size([67, 256])
# 100%|██████████| 1/1 [00:00<00:00, 13.86it/s]
# Epoch 3 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328770.6768
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328770.6768
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2163
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2163
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0637
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0637
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6567
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.6567
# 0it [00:00, ?it/s]after squeeze : torch.Size([67, 256])
# 100%|██████████| 1/1 [00:00<00:00, 12.67it/s]
# Epoch 4 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328771.7871
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328771.7871
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0453
# 	Loss_MB/train_phase/train_stream/Task000 = 2.0453
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0700
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0700
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7164
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.7164
# 0it [00:00, ?it/s]after squeeze : torch.Size([67, 256])
# 100%|██████████| 1/1 [00:00<00:00, 14.39it/s]
# Epoch 5 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328772.8975
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328772.8975
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8545
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8545
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0598
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0598
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7015
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.7015
# 0it [00:00, ?it/s]after squeeze : torch.Size([67, 256])
# 100%|██████████| 1/1 [00:00<00:00, 14.23it/s]
# Epoch 6 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328774.0078
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328774.0078
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6583
# 	Loss_MB/train_phase/train_stream/Task000 = 1.6583
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0609
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0609
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6716
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.6716
# 0it [00:00, ?it/s]after squeeze : torch.Size([67, 256])
# 100%|██████████| 1/1 [00:00<00:00, 13.38it/s]
# Epoch 7 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328775.1182
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328775.1182
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.4832
# 	Loss_MB/train_phase/train_stream/Task000 = 1.4832
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0653
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0653
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6567
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.6567
# 0it [00:00, ?it/s]after squeeze : torch.Size([67, 256])
# 100%|██████████| 1/1 [00:00<00:00, 10.52it/s]
# Epoch 8 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328776.2285
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328776.2285
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3544
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3544
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0856
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0856
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6269
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.6269
# 0it [00:00, ?it/s]after squeeze : torch.Size([67, 256])
# 100%|██████████| 1/1 [00:00<00:00, 13.65it/s]
# Epoch 9 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328777.3389
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328777.3389
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.2758
# 	Loss_MB/train_phase/train_stream/Task000 = 1.2758
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0646
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0646
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6716
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.6716
# after squeeze : torch.Size([67, 256])
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([70, 256])
# 100%|██████████| 1/1 [00:00<00:00, 14.18it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 12.7000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 328778.5742
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 2.8699
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3429
# -- Starting eval on experience 1 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 24.08it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 12.1000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 328779.2715
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 4.5913
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 38.17it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 14.8000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 328779.9688
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 4.6888
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 39.40it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 14.7000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 328780.6660
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 5.5318
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 36.91it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 15.0000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 328781.3633
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 5.5894
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 41.09it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 15.4000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 328782.0605
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 7.0771
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- Starting eval on experience 6 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 41.74it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 15.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 328782.7578
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp006 = 4.2477
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp006 = 0.0000
# -- >> End of eval phase << --
# 	DiskUsage_Stream/eval_phase/test_stream/Task000 = 328782.7578
# 	Loss_Stream/eval_phase/test_stream/Task000 = 4.7417
# 	StreamForgetting/eval_phase/test_stream = 0.0000
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0774
# Start of experience:  1
# Current Classes:  [16, 4]
# -- >> Start of training phase << --
# 0it [00:00, ?it/s]after squeeze : torch.Size([36, 256])
# 100%|██████████| 1/1 [00:00<00:00, 14.55it/s]
# Epoch 0 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328784.0605
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328784.0605
# 	Loss_Epoch/train_phase/train_stream/Task000 = 5.7786
# 	Loss_MB/train_phase/train_stream/Task000 = 5.7786
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0579
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0579
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([36, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.76it/s]
# Epoch 1 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328785.1709
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328785.1709
# 	Loss_Epoch/train_phase/train_stream/Task000 = 4.7772
# 	Loss_MB/train_phase/train_stream/Task000 = 4.7772
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0388
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0388
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([36, 256])
# 100%|██████████| 1/1 [00:00<00:00, 21.25it/s]
# Epoch 2 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328786.2812
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328786.2812
# 	Loss_Epoch/train_phase/train_stream/Task000 = 4.0489
# 	Loss_MB/train_phase/train_stream/Task000 = 4.0489
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0384
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0384
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([36, 256])
# 100%|██████████| 1/1 [00:00<00:00, 21.94it/s]
# Epoch 3 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328787.3916
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328787.3916
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.5349
# 	Loss_MB/train_phase/train_stream/Task000 = 3.5349
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0372
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0372
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([36, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.64it/s]
# Epoch 4 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328788.5020
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328788.5020
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.1698
# 	Loss_MB/train_phase/train_stream/Task000 = 3.1698
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0393
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0393
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([36, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.04it/s]
# Epoch 5 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328789.6123
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328789.6123
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.9031
# 	Loss_MB/train_phase/train_stream/Task000 = 2.9031
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0393
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0393
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0833
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0833
# 0it [00:00, ?it/s]after squeeze : torch.Size([36, 256])
# 100%|██████████| 1/1 [00:00<00:00, 21.33it/s]
# Epoch 6 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328790.7227
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328790.7227
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.6969
# 	Loss_MB/train_phase/train_stream/Task000 = 2.6969
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0370
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0370
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4722
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.4722
# 0it [00:00, ?it/s]after squeeze : torch.Size([36, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.27it/s]
# Epoch 7 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328791.8330
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328791.8330
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.5184
# 	Loss_MB/train_phase/train_stream/Task000 = 2.5184
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0407
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0407
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4722
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.4722
# 0it [00:00, ?it/s]after squeeze : torch.Size([36, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.91it/s]
# Epoch 8 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328792.9434
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328792.9434
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.3397
# 	Loss_MB/train_phase/train_stream/Task000 = 2.3397
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0394
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0394
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4722
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.4722
# 0it [00:00, ?it/s]after squeeze : torch.Size([36, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.71it/s]
# Epoch 9 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328794.0537
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328794.0537
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1435
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1435
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0386
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0386
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4722
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.4722
# after squeeze : torch.Size([36, 256])
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([70, 256])
# 100%|██████████| 1/1 [00:00<00:00, 30.44it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 14.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 328795.2891
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.3429
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 3.2245
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 40.68it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 14.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 328796.1475
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 2.7404
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.2500
# -- Starting eval on experience 2 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 41.73it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 14.9000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 328796.8447
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 3.8791
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 42.46it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 14.9000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 328797.5420
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 4.0800
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 42.26it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 13.7000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 328798.2393
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 4.4487
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 41.49it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 14.0000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 328798.9365
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 4.9800
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- Starting eval on experience 6 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 40.69it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 14.2000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 328799.6338
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp006 = 3.6258
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp006 = 0.0000
# -- >> End of eval phase << --
# 	DiskUsage_Stream/eval_phase/test_stream/Task000 = 328799.6338
# 	Loss_Stream/eval_phase/test_stream/Task000 = 3.7931
# 	StreamForgetting/eval_phase/test_stream = 0.3429
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0323
# Start of experience:  2
# Current Classes:  [9, 17]
# -- >> Start of training phase << --
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 17.06it/s]
# Epoch 0 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328800.9365
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328800.9365
# 	Loss_Epoch/train_phase/train_stream/Task000 = 4.2624
# 	Loss_MB/train_phase/train_stream/Task000 = 4.2624
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0490
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0490
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.44it/s]
# Epoch 1 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328802.0469
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328802.0469
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.7734
# 	Loss_MB/train_phase/train_stream/Task000 = 3.7734
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0396
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0396
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 19.44it/s]
# Epoch 2 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328803.1572
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328803.1572
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.4078
# 	Loss_MB/train_phase/train_stream/Task000 = 3.4078
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0419
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0419
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 21.63it/s]
# Epoch 3 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328804.2676
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328804.2676
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.1070
# 	Loss_MB/train_phase/train_stream/Task000 = 3.1070
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0377
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0377
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 21.36it/s]
# Epoch 4 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328805.3779
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328805.3779
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.8342
# 	Loss_MB/train_phase/train_stream/Task000 = 2.8342
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0385
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0385
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4865
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.4865
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.29it/s]
# Epoch 5 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328806.4883
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328806.4883
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.5648
# 	Loss_MB/train_phase/train_stream/Task000 = 2.5648
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0401
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0401
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4865
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.4865
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.51it/s]
# Epoch 6 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328807.5986
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328807.5986
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2719
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2719
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0395
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0395
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4865
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.4865
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 19.57it/s]
# Epoch 7 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328808.7090
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328808.7090
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9421
# 	Loss_MB/train_phase/train_stream/Task000 = 1.9421
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0424
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0424
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4865
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.4865
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 21.50it/s]
# Epoch 8 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328809.8193
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328809.8193
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.5840
# 	Loss_MB/train_phase/train_stream/Task000 = 1.5840
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0371
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0371
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4865
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.4865
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 19.68it/s]
# Epoch 9 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328810.9297
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328810.9297
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.2395
# 	Loss_MB/train_phase/train_stream/Task000 = 1.2395
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0413
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0413
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4865
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.4865
# after squeeze : torch.Size([37, 256])
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([70, 256])
# 100%|██████████| 1/1 [00:00<00:00, 32.41it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 15.4000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 328812.1650
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.3429
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 5.4723
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 40.42it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 14.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 328813.0234
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 0.2500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 5.1549
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 42.58it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 14.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 328813.8818
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 3.0068
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.2500
# -- Starting eval on experience 3 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 38.26it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 14.4000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 328814.5791
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 4.9441
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 41.01it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 14.8000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 328815.2764
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 5.3068
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 38.49it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 14.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 328815.9736
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 5.2866
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- Starting eval on experience 6 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 42.46it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 14.7000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 328816.6709
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp006 = 4.3793
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp006 = 0.0000
# -- >> End of eval phase << --
# 	DiskUsage_Stream/eval_phase/test_stream/Task000 = 328816.6709
# 	Loss_Stream/eval_phase/test_stream/Task000 = 4.8587
# 	StreamForgetting/eval_phase/test_stream = 0.2964
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0323
# Start of experience:  3
# Current Classes:  [1, 2]
# -- >> Start of training phase << --
# 0it [00:00, ?it/s]after squeeze : torch.Size([38, 256])
# 100%|██████████| 1/1 [00:00<00:00, 16.16it/s]
# Epoch 0 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328817.9736
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328817.9736
# 	Loss_Epoch/train_phase/train_stream/Task000 = 4.4672
# 	Loss_MB/train_phase/train_stream/Task000 = 4.4672
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0518
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0518
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([38, 256])
# 100%|██████████| 1/1 [00:00<00:00, 21.56it/s]
# Epoch 1 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328819.0840
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328819.0840
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.5785
# 	Loss_MB/train_phase/train_stream/Task000 = 3.5785
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0373
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0373
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([38, 256])
# 100%|██████████| 1/1 [00:00<00:00, 21.11it/s]
# Epoch 2 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328820.1943
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328820.1943
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.9456
# 	Loss_MB/train_phase/train_stream/Task000 = 2.9456
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0376
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0376
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([38, 256])
# 100%|██████████| 1/1 [00:00<00:00, 18.24it/s]
# Epoch 3 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328821.3047
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328821.3047
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.4740
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4740
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0453
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0453
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([38, 256])
# 100%|██████████| 1/1 [00:00<00:00, 21.25it/s]
# Epoch 4 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328822.4150
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328822.4150
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0907
# 	Loss_MB/train_phase/train_stream/Task000 = 2.0907
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0382
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0382
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.5000
# 0it [00:00, ?it/s]after squeeze : torch.Size([38, 256])
# 100%|██████████| 1/1 [00:00<00:00, 19.15it/s]
# Epoch 5 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328823.5254
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328823.5254
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7563
# 	Loss_MB/train_phase/train_stream/Task000 = 1.7563
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0432
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0432
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.5000
# 0it [00:00, ?it/s]after squeeze : torch.Size([38, 256])
# 100%|██████████| 1/1 [00:00<00:00, 19.36it/s]
# Epoch 6 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328824.6357
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328824.6357
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.4661
# 	Loss_MB/train_phase/train_stream/Task000 = 1.4661
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0426
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0426
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.5000
# 0it [00:00, ?it/s]after squeeze : torch.Size([38, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.46it/s]
# Epoch 7 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328825.7461
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328825.7461
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.2308
# 	Loss_MB/train_phase/train_stream/Task000 = 1.2308
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0398
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0398
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.5000
# 0it [00:00, ?it/s]after squeeze : torch.Size([38, 256])
# 100%|██████████| 1/1 [00:00<00:00, 18.26it/s]
# Epoch 8 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328826.8564
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328826.8564
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.0574
# 	Loss_MB/train_phase/train_stream/Task000 = 1.0574
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0458
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0458
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.5000
# 0it [00:00, ?it/s]after squeeze : torch.Size([38, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.23it/s]
# Epoch 9 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328827.9668
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328827.9668
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.9354
# 	Loss_MB/train_phase/train_stream/Task000 = 0.9354
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0404
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0404
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.5000
# after squeeze : torch.Size([38, 256])
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([70, 256])
# 100%|██████████| 1/1 [00:00<00:00, 29.18it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 14.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 328829.2021
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.3429
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 7.8770
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 41.97it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 15.2000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 328830.0605
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 0.2500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 8.1267
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 42.28it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 15.6000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 328830.9189
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp002 = 0.2500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 5.8317
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 40.22it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 13.8000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 328831.7773
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 3.7684
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.2500
# -- Starting eval on experience 4 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 39.89it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 15.2000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 328832.4746
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 6.5798
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 40.85it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 14.9000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 328833.1719
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 6.2453
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- Starting eval on experience 6 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 38.75it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 12.3000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 328833.8691
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp006 = 6.6453
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp006 = 0.0000
# -- >> End of eval phase << --
# 	DiskUsage_Stream/eval_phase/test_stream/Task000 = 328833.8691
# 	Loss_Stream/eval_phase/test_stream/Task000 = 6.5783
# 	StreamForgetting/eval_phase/test_stream = 0.2810
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0323
# Start of experience:  4
# Current Classes:  [11, 6]
# -- >> Start of training phase << --
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.42it/s]
# Epoch 0 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328835.1719
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328835.1719
# 	Loss_Epoch/train_phase/train_stream/Task000 = 5.9733
# 	Loss_MB/train_phase/train_stream/Task000 = 5.9733
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0392
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0392
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 21.34it/s]
# Epoch 1 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328836.2822
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328836.2822
# 	Loss_Epoch/train_phase/train_stream/Task000 = 4.7012
# 	Loss_MB/train_phase/train_stream/Task000 = 4.7012
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0380
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0380
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 21.03it/s]
# Epoch 2 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328837.3926
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328837.3926
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.7521
# 	Loss_MB/train_phase/train_stream/Task000 = 3.7521
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0379
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0379
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 19.91it/s]
# Epoch 3 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328838.5029
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328838.5029
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.1041
# 	Loss_MB/train_phase/train_stream/Task000 = 3.1041
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0406
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0406
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 21.83it/s]
# Epoch 4 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328839.6133
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328839.6133
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.6999
# 	Loss_MB/train_phase/train_stream/Task000 = 2.6999
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0366
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0366
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.10it/s]
# Epoch 5 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328840.7236
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328840.7236
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.4555
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4555
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0402
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0402
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.72it/s]
# Epoch 6 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328841.8340
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328841.8340
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2940
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2940
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0392
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0392
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.39it/s]
# Epoch 7 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328842.9443
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328842.9443
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1585
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1585
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0398
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0398
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5405
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.5405
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.78it/s]
# Epoch 8 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328844.0547
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328844.0547
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0132
# 	Loss_MB/train_phase/train_stream/Task000 = 2.0132
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0390
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0390
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5676
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.5676
# 0it [00:00, ?it/s]after squeeze : torch.Size([37, 256])
# 100%|██████████| 1/1 [00:00<00:00, 18.42it/s]
# Epoch 9 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328845.1650
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328845.1650
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8427
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8427
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0445
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0445
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5946
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.5946
# after squeeze : torch.Size([37, 256])
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([70, 256])
# 100%|██████████| 1/1 [00:00<00:00, 25.53it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 15.6000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 328846.4004
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.3429
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 4.3635
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 36.42it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 11.6000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 328847.2588
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 0.2500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 4.8898
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 34.16it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 11.8000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 328848.1172
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp002 = 0.2500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 4.3995
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 33.26it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 9.2000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 328848.9756
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp003 = 0.2500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 3.1836
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 30.00it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 9.6000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 328849.8330
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 2.9142
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.3500
# -- Starting eval on experience 5 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 33.60it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 10.4000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 328850.5293
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 3.4670
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- Starting eval on experience 6 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 36.58it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 11.3000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 328851.2266
# ...
# 	Loss_MB/train_phase/train_stream/Task000 = 1.2882
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0400
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0400
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3947
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.3947
# 0it [00:00, ?it/s]after squeeze : torch.Size([38, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.57it/s]
# Epoch 7 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328860.3018
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328860.3018
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.0375
# 	Loss_MB/train_phase/train_stream/Task000 = 1.0375
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0402
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0402
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3947
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.3947
# 0it [00:00, ?it/s]after squeeze : torch.Size([38, 256])
# 100%|██████████| 1/1 [00:00<00:00, 19.53it/s]
# Epoch 8 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328861.4121
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328861.4121
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.9017
# 	Loss_MB/train_phase/train_stream/Task000 = 0.9017
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0420
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0420
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4474
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.4474
# 0it [00:00, ?it/s]after squeeze : torch.Size([38, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.26it/s]
# Epoch 9 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328862.5225
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328862.5225
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.8504
# 	Loss_MB/train_phase/train_stream/Task000 = 0.8504
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0405
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0405
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4474
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.4474
# after squeeze : torch.Size([38, 256])
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([70, 256])
# 100%|██████████| 1/1 [00:00<00:00, 31.45it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 14.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 328863.7578
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.3429
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 8.6380
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 38.72it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 17.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 328864.6162
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 0.2500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 10.0379
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 36.30it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 17.2000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 328865.4756
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp002 = 0.2500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 9.8671
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 40.64it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 15.6000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 328866.3340
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp003 = 0.2500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 8.4441
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 40.49it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 16.6000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 328867.1924
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp004 = 0.3500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 6.8404
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 43.68it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 17.1000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 328868.0508
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 3.2849
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.2250
# -- Starting eval on experience 6 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 42.07it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 17.1000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 328868.7480
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp006 = 7.9410
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp006 = 0.0000
# -- >> End of eval phase << --
# 	DiskUsage_Stream/eval_phase/test_stream/Task000 = 328868.7480
# 	Loss_Stream/eval_phase/test_stream/Task000 = 7.9396
# 	StreamForgetting/eval_phase/test_stream = 0.2886
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0290
# Start of experience:  6
# Current Classes:  [14, 15]
# -- >> Start of training phase << --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 17.28it/s]
# Epoch 0 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328870.0508
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328870.0508
# 	Loss_Epoch/train_phase/train_stream/Task000 = 8.6050
# 	Loss_MB/train_phase/train_stream/Task000 = 8.6050
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0467
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0467
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 21.04it/s]
# Epoch 1 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328871.1611
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328871.1611
# 	Loss_Epoch/train_phase/train_stream/Task000 = 6.7967
# 	Loss_MB/train_phase/train_stream/Task000 = 6.7967
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0381
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0381
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 20.15it/s]
# Epoch 2 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328872.2715
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328872.2715
# 	Loss_Epoch/train_phase/train_stream/Task000 = 5.3721
# 	Loss_MB/train_phase/train_stream/Task000 = 5.3721
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0399
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0399
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 21.11it/s]
# Epoch 3 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328873.3818
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328873.3818
# 	Loss_Epoch/train_phase/train_stream/Task000 = 4.3214
# 	Loss_MB/train_phase/train_stream/Task000 = 4.3214
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0387
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0387
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 17.78it/s]
# Epoch 4 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328874.4922
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328874.4922
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.6123
# 	Loss_MB/train_phase/train_stream/Task000 = 3.6123
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0469
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0469
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 21.43it/s]
# Epoch 5 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328875.6025
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328875.6025
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.1684
# 	Loss_MB/train_phase/train_stream/Task000 = 3.1684
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0378
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0378
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 21.48it/s]
# Epoch 6 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328876.7129
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328876.7129
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.8926
# 	Loss_MB/train_phase/train_stream/Task000 = 2.8926
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0369
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0369
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 19.07it/s]
# Epoch 7 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328877.8232
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328877.8232
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.6994
# 	Loss_MB/train_phase/train_stream/Task000 = 2.6994
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0435
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0435
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 19.58it/s]
# Epoch 8 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328878.9336
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328878.9336
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.5334
# 	Loss_MB/train_phase/train_stream/Task000 = 2.5334
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0413
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0413
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2500
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.2500
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 21.96it/s]
# Epoch 9 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 328880.0439
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 328880.0439
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.3653
# 	Loss_MB/train_phase/train_stream/Task000 = 2.3653
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0369
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0369
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.5000
# after squeeze : torch.Size([40, 256])
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([70, 256])
# 100%|██████████| 1/1 [00:00<00:00, 28.77it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 16.0000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 328881.2793
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.3429
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 3.4081
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 42.13it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 17.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 328882.1377
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 0.2500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 3.7495
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 41.10it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 17.0000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 328882.9961
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp002 = 0.2500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 4.4629
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 41.22it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 16.8000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 328883.8545
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp003 = 0.2500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 4.8121
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 42.32it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 16.9000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 328884.7129
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp004 = 0.3500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 4.2929
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 32.70it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 16.1000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 328885.5713
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp005 = 0.2250
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 3.3019
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- Starting eval on experience 6 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 34.95it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 15.8000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 328886.4297
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp006 = 2.7759
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp006 = 0.2500
# -- >> End of eval phase << --
# 	DiskUsage_Stream/eval_phase/test_stream/Task000 = 328886.4297
# 	Loss_Stream/eval_phase/test_stream/Task000 = 3.7883
# 	StreamForgetting/eval_phase/test_stream = 0.2780
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0323

# %%
print('Computing accuracy on the whole test set')
    # test also returns a dictionary which contains all the metric values
res = cl_strategy.eval(benchmark.test_stream)
# Out:
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([70, 256])
# 100%|██████████| 1/1 [00:00<00:00, 30.22it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 15.2000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 328887.7236
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.3429
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 3.4081
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 40.17it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 15.2000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 328888.5820
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 0.2500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 3.7495
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 38.78it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 15.8000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 328889.4404
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp002 = 0.2500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 4.4629
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 40.28it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 16.7000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 328890.2988
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp003 = 0.2500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 4.8121
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 43.67it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 17.6000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 328891.1572
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp004 = 0.3500
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 4.2929
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 41.55it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 18.0000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 328892.0156
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp005 = 0.2250
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 3.3019
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- Starting eval on experience 6 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([40, 256])
# 100%|██████████| 1/1 [00:00<00:00, 38.13it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 16.7000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 328892.8740
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp006 = 2.7759
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp006 = 0.2500
# -- >> End of eval phase << --
# 	DiskUsage_Stream/eval_phase/test_stream/Task000 = 328892.8740
# 	Loss_Stream/eval_phase/test_stream/Task000 = 3.7883
# 	StreamForgetting/eval_phase/test_stream = 0.2780
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0323

# %%
d = eval_plugin.get_last_metrics()

# %%
model4.classifier.classifier
# Out:
# Linear(in_features=256, out_features=31, bias=True)

# %%
model_incs
# Out:
# [IncrementalClassifier(
#    (classifier): Linear(in_features=256, out_features=31, bias=True)
#  ),
#  IncrementalClassifier(
#    (classifier): Linear(in_features=256, out_features=31, bias=True)
#  ),
#  IncrementalClassifier(
#    (classifier): Linear(in_features=256, out_features=31, bias=True)
#  ),
#  IncrementalClassifier(
#    (classifier): Linear(in_features=256, out_features=31, bias=True)
#  ),
#  IncrementalClassifier(
#    (classifier): Linear(in_features=256, out_features=31, bias=True)
#  ),
#  IncrementalClassifier(
#    (classifier): Linear(in_features=256, out_features=31, bias=True)
#  ),
#  IncrementalClassifier(
#    (classifier): Linear(in_features=256, out_features=31, bias=True)
#  )]

# %%
classes_exp
# Out:
# [[8, 13, 12, 5], [16, 4], [9, 17], [1, 2], [11, 6], [0, 3, 7], [14, 15]]

# %%
for experience in benchmark.train_stream:
    print("Start of experience: ", experience.current_experience)
    print("Current Classes: ", experience.classes_in_this_experience)
    targets = experience.dataset.targets
    print(set(targets))
# Out:
# Start of experience:  0
# Current Classes:  [8, 13, 12, 5]
# {8, 13, 12, 5}
# Start of experience:  1
# Current Classes:  [16, 4]
# {16, 4}
# Start of experience:  2
# Current Classes:  [9, 17]
# {9, 17}
# Start of experience:  3
# Current Classes:  [1, 2]
# {1, 2}
# Start of experience:  4
# Current Classes:  [11, 6]
# {11, 6}
# Start of experience:  5
# Current Classes:  [0, 3, 7]
# {0, 3, 7}
# Start of experience:  6
# Current Classes:  [14, 15]
# {14, 15}
