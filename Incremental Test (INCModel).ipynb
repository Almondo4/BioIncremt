# %%
import torch
from torch import nn
from torchmetrics import Accuracy, F1Score, Precision, AUROC
import pytorch_lightning as pl
import torchsummary

from torchmetrics import Accuracy, F1Score, Precision, AUROC, ConfusionMatrix
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
import pandas as pd
from avalanche.benchmarks import benchmark_with_validation_stream, nc_benchmark
from torch.utils.data import Dataset

# %%
class TorchDataset(Dataset):

    def __init__(self,filePath):

        device = 'cuda' if torch.cuda.is_available() else 'cpu'
        # Read CSV
        data = pd.read_csv(filePath)

        self.X = data.iloc[:,:-1].values
        self.targets = data.iloc[:, -1].values

        # Feature Scale if you want


        # Convert to Torch Tensors
        self.X = torch.tensor(self.X, dtype=torch.float32)
        self.targets = torch.tensor(self.targets, dtype=torch.int)

    def __len__(self):
        return len(self.targets)

    def __getitem__(self, item):

        return self.X[item], self.targets[item]


def prep_benchmark(train_loc, test_loc):
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(device)

    hdata_train = TorchDataset(train_loc)
    hdata_test = TorchDataset(test_loc)

    return benchmark_with_validation_stream(nc_benchmark(train_dataset=hdata_train, test_dataset=hdata_test
                                 , shuffle=True, seed=1234, task_labels=False, one_dataset_per_exp=True,n_experiences=31))

# %%
from avalanche.models import PNN
from avalanche.models.dynamic_modules import (
    MultiTaskModule,
    MultiHeadClassifier, IncrementalClassifier, DynamicModule,
)


class Simple1DCNN(nn.Module):
    """
    Convolutional Neural Network

    **Example**::

         from avalanche.models import SimpleCNN
         n_classes = 10 # e.g. MNIST
         model = SimpleCNN(num_classes=n_classes)
         print(model) # View model details
    """

    def __init__(self, num_classes=10):
        super(Simple1DCNN, self).__init__()

        self.features = nn.Sequential(
        nn.Conv1d(in_channels=1, out_channels=32, padding='same',  kernel_size=3,),
        nn.MaxPool1d(4),
        nn.Conv1d(in_channels=32, out_channels=32, padding='same',  kernel_size=3),
        nn.MaxPool1d(4),
        nn.Conv1d(in_channels=32, out_channels=16, padding='same',  kernel_size=3),
        nn.MaxPool1d(4),
        nn.Conv1d(in_channels=16, out_channels=16, padding='same',  kernel_size=3),
        nn.MaxPool1d(4),
        )
        self.classifier = nn.Sequential(nn.Linear(256, num_classes))


# IN MTS it doesn't even use this foward
    def forward(self, x):
        x = x.unsqueeze(dim=1)
        x = self.features(x)
        x = x.view(x.size(0), -1)
        # x = self.classifier(x, task_labels)#TODO: previously

        x = self.fc1(x)
        x = torch.relu(x)
        x = self.fc2(x)
        x = torch.relu(x)
        x = self.fc3(x)
        x = torch.log_softmax(x, dim=1)
        return x



class MTSimple1DCNN(Simple1DCNN, DynamicModule):
    """
    Convolutional Neural Network
    with multi-head classifier
    """

    def __init__(self):
        super().__init__()
        self.classifier = IncrementalClassifier(in_features=256, initial_out_features=1,masking=False)

# CHECK: `initial_out_features`. is the problem her it has to be consistant, so we are not going to use a multitask module
    def forward(self, x, ):
        x = x.unsqueeze(dim=1)
        x = self.features(x)
        x = x.view(x.size(0), -1)
        print(f'after squeeze : {x.shape}')
        x = self.classifier(x,)
        return x

# %%
# from avalanche.models import DynamicModule
# from avalanche.benchmarks import CLExperience
#
#
# class Incremental1DClassifier(DynamicModule):
#     """
#     Output layer that incrementally adds units whenever new classes are
#     encountered.
#
#     Typically used in class-incremental benchmarks where the number of
#     classes grows over time.
#     """
#
#     def __init__(
#         self,
#         in_features,
#         initial_out_features=2,
#         masking=True,
#         mask_value=-1000,
#     ):
#         """
#         :param in_features: number of input features.
#         :param initial_out_features: initial number of classes (can be
#             dynamically expanded).
#         :param masking: whether unused units should be masked (default=True).
#         :param mask_value: the value used for masked units (default=-1000).
#         """
#         super().__init__()
#         self.masking = masking
#         self.mask_value = mask_value
#
#         self.classifier = torch.nn.Linear(in_features, initial_out_features)
#         au_init = torch.zeros(initial_out_features, dtype=torch.bool)
#         self.register_buffer("active_units", au_init)
#
#
#     @torch.no_grad()
#     def adaptation(self, experience: CLExperience):
#         """If `dataset` contains unseen classes the classifier is expanded.
#
#         :param experience: data from the current experience.
#         :return:
#         """
#         in_features = self.classifier.in_features
#         old_nclasses = self.classifier.out_features
#         curr_classes = experience.classes_in_this_experience
#         new_nclasses = max(self.classifier.out_features, max(curr_classes) + 1)
#
#         # update active_units mask
#         if self.masking:
#             if old_nclasses != new_nclasses:  # expand active_units mask
#                 old_act_units = self.active_units
#                 self.active_units = torch.zeros(new_nclasses, dtype=torch.bool)
#                 self.active_units[: old_act_units.shape[0]] = old_act_units
#             # update with new active classes
#             if self.training:
#                 self.active_units[curr_classes] = 1
#
#         # update classifier weights
#         if old_nclasses == new_nclasses:
#             return
#         old_w, old_b = self.classifier.weight, self.classifier.bias
#         self.classifier = torch.nn.Linear(in_features, new_nclasses)
#         self.classifier.weight[:old_nclasses] = old_w
#         self.classifier.bias[:old_nclasses] = old_b
#
#     def forward(self, x, **kwargs):
#         """compute the output given the input `x`. This module does not use
#         the task label.
#
#         :param x:
#         :return:
#         """
#         out = self.classifier(x)
#         if self.masking:
#             out[..., torch.logical_not(self.active_units)] = self.mask_value
#         return out

# %%
class CNN1D(pl.LightningModule):
    def __init__(self, input_shape):

        self.save_hyperparameters()# to Save Hyperparameters
        super(CNN1D, self).__init__()
        self.conv1D_1 = nn.Conv1d(in_channels=1, out_channels=32, padding='same',  kernel_size=3,)
        self.maxPool1D_1 = nn.MaxPool1d(4)
        self.conv1D_2 = nn.Conv1d(in_channels=32, out_channels=32, padding='same',  kernel_size=3)
        self.maxPool1D_2 = nn.MaxPool1d(4)
        self.conv1D_3 = nn.Conv1d(in_channels=32, out_channels=16, padding='same',  kernel_size=3)
        self.maxPool1D_3 = nn.MaxPool1d(4)
        self.conv1D_4 = nn.Conv1d(in_channels=16, out_channels=16, padding='same',  kernel_size=3)
        self.maxPool1D_4 = nn.MaxPool1d(4)



        self.fc1 = nn.Linear(256, 300)
        self.fc2 = nn.Linear(300, 128)
        self.fc3 = nn.Linear(128, 31)

        self.train_accuracy = Accuracy(task='multiclass', num_classes=31)
        self.train_f1 = F1Score(task='multiclass', num_classes=31)
        self.train_precisn = Precision(task='multiclass', num_classes=31)
        self.train_rocAUC = AUROC(task='multiclass', num_classes=31)

        self.val_accuracy = Accuracy(task='multiclass', num_classes=31)
        self.val_f1 = F1Score(task='multiclass', num_classes=31)
        self.val_precisn = Precision(task='multiclass', num_classes=31)
        self.val_rocAUC = AUROC(task='multiclass', num_classes=31)

        self.test_accuracy = Accuracy(task='multiclass', num_classes=31)
        self.test_f1 = F1Score(task='multiclass', num_classes=31)
        self.test_precisn = Precision(task='multiclass', num_classes=31)
        self.test_rocAUC = AUROC(task='multiclass', num_classes=31)
        self.confusion_matrix = ConfusionMatrix(task="multiclass", num_classes=31)


    def forward(self, x):
        # block 1
        x = x.unsqueeze(dim=1)
        x = self.conv1D_1(x)
        x = torch.relu(x)
        x= self.maxPool1D_1(x)


        # block 2
        x = self.conv1D_2(x)
        x = torch.relu(x)
        x= self.maxPool1D_2(x)

        # block 3
        x = self.conv1D_3(x)
        x = torch.relu(x)
        x= self.maxPool1D_3(x)

        # block 4
        x = self.conv1D_4(x)
        x = torch.relu(x)
        x= self.maxPool1D_4(x)

        # Flatten

        x = x.reshape(x.shape[0], -1)

        x = self.fc1(x)
        x = torch.relu(x)
        x = self.fc2(x)
        x = torch.relu(x)
        x = self.fc3(x)
        x = torch.log_softmax(x, dim=1)
        return x

    def training_step(self, batch, batch_idx):
        x, y = batch
        x = x.unsqueeze(dim=1)

        y_pred = self.forward(x)
        loss = nn.CrossEntropyLoss()(y_pred,y.long())
        self.log('train_loss', loss, on_epoch=True, on_step=True,prog_bar=True)
        self.log('train_acc_step', self.train_accuracy(y_pred, y.long(), ), on_epoch=True, on_step=True,prog_bar=False)
        self.log('train_f1_step', self.train_f1(y_pred, y.long(), ), on_epoch=True, on_step=True,prog_bar=False)
        self.log('train_precision_step', self.train_precisn(y_pred, y.long(), ), on_epoch=True, on_step=True,)
        self.log('train_auc_step', self.train_rocAUC(y_pred, y.long(), ), on_epoch=True, on_step=True,prog_bar=False )
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        x = x.unsqueeze(dim=1)
        y_pred = self.forward(x)
        loss = nn.CrossEntropyLoss()(y_pred,y.long())
        self.log('validation_loss', loss)
        self.log('val_loss', loss, on_epoch=True)
        self.log('val_acc', self.val_accuracy(y_pred, y.long(), ),on_epoch=True, prog_bar=True)
        self.log('val_f1', self.val_f1(y_pred, y.long(), ),on_epoch=True, prog_bar=True)
        self.log('val_precision', self.val_precisn(y_pred, y.long(), ),on_epoch=True, prog_bar=True)
        self.log('val_auc', self.val_rocAUC(y_pred, y.long(), ),on_epoch=True, prog_bar=True)
        return loss

    def test_step(self, batch, batch_idx):
        # this is the test loop
        x, y = batch
        x = x.unsqueeze(dim=1)
        # img = x.view(-1,3,IMG_SIZE,IMG_SIZE)
        y_pred = self.forward(x)
        loss = nn.CrossEntropyLoss()(y_pred,y.long())
        # self.log('test_loss', loss)
        # self.log('test_loss', loss, on_epoch=True)
        self.log('test_acc', self.test_accuracy(y_pred, y.long(), ),)
        self.log('test_f1', self.test_f1(y_pred, y.long(), ),)
        self.log('test_precision', self.test_precisn(y_pred, y.long(), ),)
        self.log('test_auc', self.test_rocAUC(y_pred, y.long(), ),)
        self.confusion_matrix(y_pred, y.long())
        print(self.confusion_matrix)
        # self.logger.experiment.add_confusion_matrix('confusion_matrix', self.confusion_matrix)
        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=1e-3)
        return optimizer

# model = CNN1D(input_shape=4097,)

# %%
from avalanche.models import MTSimpleMLP, MTSimpleCNN
from torch.nn import CrossEntropyLoss
from avalanche.training import Naive, EWC
from avalanche.evaluation.metrics import accuracy_metrics, loss_metrics, timing_metrics, forgetting_metrics, \
    cpu_usage_metrics, disk_usage_metrics
from avalanche.training.plugins import EvaluationPlugin
from avalanche.logging import TensorboardLogger, TextLogger, InteractiveLogger
import avalanche as avl




benchmark = prep_benchmark(train_loc='./DATA/TRAIN_DATA.csv', test_loc='./DATA/TEST_DATA.csv')


# log to Tensorboard
tb_logger = TensorboardLogger()

# log to text file
text_logger = TextLogger(open('log.txt', 'a'))

# print to stdout
interactive_logger = InteractiveLogger()

eval_plugin = EvaluationPlugin(
    accuracy_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    loss_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    timing_metrics(epoch=True, epoch_running=True),
    forgetting_metrics(experience=True, stream=True),
    cpu_usage_metrics(experience=True),
    # confusion_matrix_metrics(num_classes=benchmark['inc_bench'].n_classes, save_image=False,
    #                          stream=True),
    disk_usage_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    loggers=[interactive_logger, text_logger, tb_logger]
)

# CREATE THE STRATEGY INSTANCE (EWC)
# model2 = avl.models.PNN(in_features=4096,hidden_features_per_column=1000,num_layers=7,)
# model3 =  MTSimpleCNN()
model4 = MTSimple1DCNN()
# TODO: 4096 is too much i might need to pass thought the cnn first and then pass it to the pnn
cl_strategy = EWC(
    model4, torch.optim.Adam(model4.parameters(), lr=0.001,),
    CrossEntropyLoss(), train_mb_size=500, train_epochs=10, eval_mb_size=100,
    evaluator=eval_plugin,ewc_lambda=0.4)

# TRAINING LOOP
print('Starting experiment...')
results = []
model_incs = []
classes_exp= []
for experience in benchmark.train_stream:
    print("Start of experience: ", experience.current_experience)
    print("Current Classes: ", experience.classes_in_this_experience)
    model_incs.append(model4.classifier.classifier)
    classes_exp.append(experience.classes_in_this_experience)
    # train returns a dictionary which contains all the metric values
    res = cl_strategy.train(experience)
    print('Training completed')

    print('Computing accuracy on the whole test set')
    # test also returns a dictionary which contains all the metric values
    results.append(cl_strategy.eval(benchmark.test_stream))
# Out:
# cpu
# Starting experiment...
# Start of experience:  0
# Current Classes:  [27]
# -- >> Start of training phase << --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 25.46it/s]
# Epoch 0 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230723.9111
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230723.9111
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.6529
# 	Loss_MB/train_phase/train_stream/Task000 = 3.6529
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0232
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0232
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 31.53it/s]
# Epoch 1 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230725.0137
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230725.0137
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.3697
# 	Loss_MB/train_phase/train_stream/Task000 = 3.3697
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0251
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0251
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 40.16it/s]
# Epoch 2 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230726.1240
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230726.1240
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.0957
# 	Loss_MB/train_phase/train_stream/Task000 = 3.0957
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0182
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0182
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 39.80it/s]
# Epoch 3 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230727.2344
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230727.2344
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.8086
# 	Loss_MB/train_phase/train_stream/Task000 = 2.8086
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0187
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0187
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 39.97it/s]
# Epoch 4 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230728.3447
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230728.3447
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.4866
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4866
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0181
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0181
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 39.91it/s]
# Epoch 5 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230729.4551
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230729.4551
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1168
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1168
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0174
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0174
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 43.78it/s]
# Epoch 6 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230730.5654
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230730.5654
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6886
# 	Loss_MB/train_phase/train_stream/Task000 = 1.6886
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0164
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0164
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 45.94it/s]
# Epoch 7 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230731.6758
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230731.6758
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.2162
# 	Loss_MB/train_phase/train_stream/Task000 = 1.2162
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0150
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0150
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 45.34it/s]
# Epoch 8 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230732.7861
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230732.7861
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.7490
# 	Loss_MB/train_phase/train_stream/Task000 = 0.7490
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0143
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0143
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 43.65it/s]
# Epoch 9 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230733.8965
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230733.8965
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.3674
# 	Loss_MB/train_phase/train_stream/Task000 = 0.3674
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0152
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0152
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# after squeeze : torch.Size([10, 256])
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 72.22it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 16.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 230735.1318
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.1542
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 1.0000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 65.39it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 15.2000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 230735.8291
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 5.9964
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 61.98it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 15.3000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 230736.5264
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 3.9755
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 66.49it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 13.9000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 230737.2236
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 6.4469
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 56.58it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 11.3000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 230737.9209
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 5.2373
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 66.65it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 14.4000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 230738.6182
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 5.5164
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- Starting eval on experience 6 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 71.48it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 13.7000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 230739.3154
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp006 = 5.4912
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp006 = 0.0000
# -- Starting eval on experience 7 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 71.87it/s]
# > Eval on experience 7 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp007 = 14.9000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp007 = 230740.0127
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp007 = 4.5820
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp007 = 0.0000
# -- Starting eval on experience 8 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 67.18it/s]
# > Eval on experience 8 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp008 = 16.1000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp008 = 230740.7100
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp008 = 6.0518
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp008 = 0.0000
# -- Starting eval on experience 9 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 70.65it/s]
# > Eval on experience 9 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp009 = 16.2000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp009 = 230741.4072
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp009 = 6.6873
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp009 = 0.0000
# -- Starting eval on experience 10 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 66.72it/s]
# > Eval on experience 10 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp010 = 14.0000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp010 = 230742.1055
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp010 = 4.8178
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp010 = 0.0000
# -- Starting eval on experience 11 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 66.74it/s]
# > Eval on experience 11 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp011 = 15.6000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp011 = 230742.8047
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp011 = 5.9020
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp011 = 0.0000
# -- Starting eval on experience 12 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 66.33it/s]
# > Eval on experience 12 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp012 = 14.8000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp012 = 230743.5039
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp012 = 6.1804
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp012 = 0.0000
# -- Starting eval on experience 13 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 68.72it/s]
# > Eval on experience 13 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp013 = 16.1000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp013 = 230744.2031
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp013 = 4.8785
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp013 = 0.0000
# -- Starting eval on experience 14 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 71.34it/s]
# > Eval on experience 14 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp014 = 16.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp014 = 230744.9023
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp014 = 5.4540
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp014 = 0.0000
# -- Starting eval on experience 15 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 66.25it/s]
# > Eval on experience 15 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp015 = 15.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp015 = 230745.6016
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp015 = 5.4439
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp015 = 0.0000
# -- Starting eval on experience 16 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 70.87it/s]
# > Eval on experience 16 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp016 = 15.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp016 = 230746.3008
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp016 = 6.5288
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp016 = 0.0000
# -- Starting eval on experience 17 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 67.88it/s]
# > Eval on experience 17 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp017 = 15.3000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp017 = 230747.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp017 = 5.2219
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp017 = 0.0000
# -- Starting eval on experience 18 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 68.71it/s]
# > Eval on experience 18 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp018 = 16.3000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp018 = 230747.6992
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp018 = 3.1065
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp018 = 0.0000
# -- Starting eval on experience 19 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 71.38it/s]
# > Eval on experience 19 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp019 = 15.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp019 = 230748.3984
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp019 = 5.2241
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp019 = 0.0000
# -- Starting eval on experience 20 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 64.86it/s]
# > Eval on experience 20 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp020 = 16.2000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp020 = 230749.0977
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp020 = 5.2470
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp020 = 0.0000
# -- Starting eval on experience 21 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 65.57it/s]
# > Eval on experience 21 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp021 = 15.4000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp021 = 230749.7969
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp021 = 5.1509
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp021 = 0.0000
# -- Starting eval on experience 22 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 67.88it/s]
# > Eval on experience 22 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp022 = 15.6000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp022 = 230750.4961
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp022 = 4.4141
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp022 = 0.0000
# -- Starting eval on experience 23 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 69.38it/s]
# > Eval on experience 23 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp023 = 16.1000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp023 = 230751.1953
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp023 = 6.1745
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp023 = 0.0000
# -- Starting eval on experience 24 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 68.10it/s]
# > Eval on experience 24 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp024 = 16.9000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp024 = 230751.8945
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp024 = 5.4567
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp024 = 0.0000
# -- Starting eval on experience 25 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 66.90it/s]
# > Eval on experience 25 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp025 = 16.4000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp025 = 230752.5938
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp025 = 5.5058
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp025 = 0.0000
# -- Starting eval on experience 26 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 65.09it/s]
# > Eval on experience 26 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp026 = 15.3000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp026 = 230753.2930
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp026 = 5.9087
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp026 = 0.0000
# -- Starting eval on experience 27 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 64.40it/s]
# > Eval on experience 27 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp027 = 15.3000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp027 = 230753.9922
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp027 = 3.1594
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp027 = 0.0000
# -- Starting eval on experience 28 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 64.68it/s]
# > Eval on experience 28 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp028 = 13.8000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp028 = 230754.6914
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp028 = 6.2872
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp028 = 0.0000
# -- Starting eval on experience 29 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 62.03it/s]
# > Eval on experience 29 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp029 = 15.3000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp029 = 230755.3906
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp029 = 4.5136
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp029 = 0.0000
# -- Starting eval on experience 30 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 64.54it/s]
# > Eval on experience 30 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp030 = 14.0000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp030 = 230756.0898
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp030 = 4.9584
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp030 = 0.0000
# -- >> End of eval phase << --
# 	DiskUsage_Stream/eval_phase/test_stream/Task000 = 230756.0898
# 	Loss_Stream/eval_phase/test_stream/Task000 = 5.1508
# 	StreamForgetting/eval_phase/test_stream = 0.0000
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0323
# Start of experience:  1
# Current Classes:  [22]
# -- >> Start of training phase << --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 43.93it/s]
# Epoch 0 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230757.3936
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230757.3936
# 	Loss_Epoch/train_phase/train_stream/Task000 = 6.0724
# 	Loss_MB/train_phase/train_stream/Task000 = 6.0724
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0155
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0155
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 41.63it/s]
# Epoch 1 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230758.5039
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230758.5039
# 	Loss_Epoch/train_phase/train_stream/Task000 = 4.8723
# 	Loss_MB/train_phase/train_stream/Task000 = 4.8723
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0168
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0168
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 41.50it/s]
# Epoch 2 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230759.6143
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230759.6143
# 	Loss_Epoch/train_phase/train_stream/Task000 = 4.0005
# 	Loss_MB/train_phase/train_stream/Task000 = 4.0005
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0172
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0172
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 41.22it/s]
# Epoch 3 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230760.7246
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230760.7246
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.3840
# 	Loss_MB/train_phase/train_stream/Task000 = 3.3840
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0159
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0159
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 42.83it/s]
# Epoch 4 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230761.8350
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230761.8350
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.9390
# 	Loss_MB/train_phase/train_stream/Task000 = 2.9390
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0161
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0161
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 45.51it/s]
# Epoch 5 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230762.9453
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230762.9453
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.6063
# 	Loss_MB/train_phase/train_stream/Task000 = 2.6063
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0154
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0154
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 41.72it/s]
# Epoch 6 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230764.0557
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230764.0557
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.3337
# 	Loss_MB/train_phase/train_stream/Task000 = 2.3337
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0167
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0167
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 40.34it/s]
# Epoch 7 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230765.1660
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230765.1660
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0829
# 	Loss_MB/train_phase/train_stream/Task000 = 2.0829
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0170
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0170
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 42.38it/s]
# Epoch 8 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230766.2764
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230766.2764
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8304
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8304
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0159
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0159
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.2000
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 42.07it/s]
# Epoch 9 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230767.3867
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230767.3867
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.5595
# 	Loss_MB/train_phase/train_stream/Task000 = 1.5595
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0158
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0158
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# after squeeze : torch.Size([10, 256])
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 69.86it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 14.4000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 230768.6221
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 1.7273
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 62.05it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 14.0000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 230769.4805
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 1.2386
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 1.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 54.03it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 13.0000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 230770.1777
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 3.1622
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 64.69it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 11.9000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 230770.8750
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 3.6350
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 60.21it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 12.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 230771.5723
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 3.8927
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 65.47it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 13.7000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 230772.2695
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 4.2257
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- Starting eval on experience 6 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 78.60it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 15.7000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 230772.9668
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp006 = 4.4208
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp006 = 0.0000
# -- Starting eval on experience 7 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 62.83it/s]
# > Eval on experience 7 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp007 = 10.9000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp007 = 230773.6641
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp007 = 3.9891
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp007 = 0.0000
# -- Starting eval on experience 8 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 62.14it/s]
# > Eval on experience 8 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp008 = 13.3000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp008 = 230774.3613
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp008 = 4.6183
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp008 = 0.0000
# -- Starting eval on experience 9 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 60.85it/s]
# > Eval on experience 9 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp009 = 11.2000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp009 = 230775.0586
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp009 = 4.5742
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp009 = 0.0000
# -- Starting eval on experience 10 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 66.45it/s]
# > Eval on experience 10 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp010 = 12.6000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp010 = 230775.7568
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp010 = 3.4285
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp010 = 0.0000
# -- Starting eval on experience 11 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 70.77it/s]
# > Eval on experience 11 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp011 = 14.0000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp011 = 230776.4561
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp011 = 4.1901
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Ex
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp030 = 0.0000
# -- >> End of eval phase << --
# 	DiskUsage_Stream/eval_phase/test_stream/Task000 = 230789.7412
# 	Loss_Stream/eval_phase/test_stream/Task000 = 3.8458
# 	StreamForgetting/eval_phase/test_stream = 1.0000
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0323
# Start of experience:  2
# Current Classes:  [29]
# -- >> Start of training phase << --
# 0it [00:00, ?it/s]after squeeze : torch.Size([9, 256])
# 100%|██████████| 1/1 [00:00<00:00, 40.32it/s]
# Epoch 0 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230791.0449
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230791.0449
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.1526
# 	Loss_MB/train_phase/train_stream/Task000 = 3.1526
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0175
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0175
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([9, 256])
# 100%|██████████| 1/1 [00:00<00:00, 40.01it/s]
# Epoch 1 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230792.1553
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230792.1553
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.6894
# 	Loss_MB/train_phase/train_stream/Task000 = 2.6894
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0181
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0181
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([9, 256])
# 100%|██████████| 1/1 [00:00<00:00, 42.22it/s]
# Epoch 2 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230793.2656
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230793.2656
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2316
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2316
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0166
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0166
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([9, 256])
# 100%|██████████| 1/1 [00:00<00:00, 45.64it/s]
# Epoch 3 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230794.3760
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230794.3760
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7466
# 	Loss_MB/train_phase/train_stream/Task000 = 1.7466
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0148
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0148
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([9, 256])
# 100%|██████████| 1/1 [00:00<00:00, 41.08it/s]
# Epoch 4 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230795.4863
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230795.4863
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.2448
# 	Loss_MB/train_phase/train_stream/Task000 = 1.2448
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0171
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0171
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([9, 256])
# 100%|██████████| 1/1 [00:00<00:00, 39.16it/s]
# Epoch 5 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230796.5967
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230796.5967
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.7662
# 	Loss_MB/train_phase/train_stream/Task000 = 0.7662
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0176
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0176
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([9, 256])
# 100%|██████████| 1/1 [00:00<00:00, 39.18it/s]
# Epoch 6 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230797.7070
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230797.7070
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.3857
# 	Loss_MB/train_phase/train_stream/Task000 = 0.3857
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0181
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0181
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([9, 256])
# 100%|██████████| 1/1 [00:00<00:00, 42.36it/s]
# Epoch 7 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230798.8174
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230798.8174
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.1555
# 	Loss_MB/train_phase/train_stream/Task000 = 0.1555
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0160
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0160
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([9, 256])
# 100%|██████████| 1/1 [00:00<00:00, 43.37it/s]
# Epoch 8 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230799.9277
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230799.9277
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0542
# 	Loss_MB/train_phase/train_stream/Task000 = 0.0542
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0154
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0154
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 0it [00:00, ?it/s]after squeeze : torch.Size([9, 256])
# 100%|██████████| 1/1 [00:00<00:00, 38.98it/s]
# Epoch 9 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 230801.0381
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 230801.0381
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0190
# 	Loss_MB/train_phase/train_stream/Task000 = 0.0190
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0176
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.0176
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# after squeeze : torch.Size([9, 256])
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 70.45it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 13.1000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 230802.2734
# ...
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 13.2765
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 65.33it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 14.9000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 231815.7002
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Ex
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp021 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp021 = 11.0728
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp021 = 0.0000
# -- Starting eval on experience 22 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 70.57it/s]
# > Eval on experience 22 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp022 = 12.0000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp022 = 231832.9951
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp022 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp022 = 11.3996
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp022 = 0.0000
# -- Starting eval on experience 23 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 58.36it/s]
# > Eval on experience 23 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp023 = 9.7000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp023 = 231833.8613
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp023 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp023 = 10.1747
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp023 = 0.0000
# -- Starting eval on experience 24 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 56.18it/s]
# > Eval on experience 24 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp024 = 11.4000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp024 = 231834.7266
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp024 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp024 = 8.6394
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp024 = 0.0000
# -- Starting eval on experience 25 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 76.21it/s]
# > Eval on experience 25 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp025 = 16.7000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp025 = 231835.5918
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp025 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp025 = 8.9132
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp025 = 0.0000
# -- Starting eval on experience 26 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 75.60it/s]
# > Eval on experience 26 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp026 = 16.3000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp026 = 231836.4570
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp026 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp026 = 7.5199
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp026 = 0.0000
# -- Starting eval on experience 27 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 70.60it/s]
# > Eval on experience 27 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp027 = 14.4000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp027 = 231837.3223
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp027 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp027 = 8.9019
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp027 = 0.0000
# -- Starting eval on experience 28 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 74.25it/s]
# > Eval on experience 28 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp028 = 16.7000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp028 = 231838.1875
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp028 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp028 = 5.4369
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp028 = 0.0000
# -- Starting eval on experience 29 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 71.14it/s]
# > Eval on experience 29 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp029 = 16.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp029 = 231839.0527
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp029 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp029 = 3.7139
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp029 = 0.0000
# -- Starting eval on experience 30 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 68.56it/s]
# > Eval on experience 30 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp030 = 14.6000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp030 = 231839.9180
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp030 = 0.0321
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp030 = 1.0000
# -- >> End of eval phase << --
# 	DiskUsage_Stream/eval_phase/test_stream/Task000 = 231839.9180
# 	Loss_Stream/eval_phase/test_stream/Task000 = 9.4629
# 	StreamForgetting/eval_phase/test_stream = 0.9967
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0323

# %%
print('Computing accuracy on the whole test set')
    # test also returns a dictionary which contains all the metric values
res = cl_strategy.eval(benchmark.test_stream)
# Out:
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 70.61it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 15.6000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 231841.2207
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 10.4312
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 61.41it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 15.6000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 231842.0850
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 13.2765
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 68.43it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 15.6000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 231842.9492
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp002 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 11.1511
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 72.61it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 16.7000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 231843.8135
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp003 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 11.1909
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 69.84it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 16.4000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 231844.6777
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp004 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 12.2446
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 74.10it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 17.4000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp005 = 231845.5420
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp005 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 9.7052
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- Starting eval on experience 6 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 62.71it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 15.7000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp006 = 231846.4053
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp006 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp006 = 9.8929
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp006 = 0.0000
# -- Starting eval on experience 7 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 67.75it/s]
# > Eval on experience 7 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp007 = 16.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp007 = 231847.2686
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp007 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp007 = 6.7744
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp007 = 0.0000
# -- Starting eval on experience 8 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 67.87it/s]
# > Eval on experience 8 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp008 = 15.9000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp008 = 231848.1318
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp008 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp008 = 8.5192
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp008 = 0.0000
# -- Starting eval on experience 9 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00,
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp026 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp026 = 7.5199
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp026 = 0.0000
# -- Starting eval on experience 27 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 69.20it/s]
# > Eval on experience 27 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp027 = 16.1000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp027 = 231864.5781
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp027 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp027 = 8.9019
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp027 = 0.0000
# -- Starting eval on experience 28 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 66.56it/s]
# > Eval on experience 28 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp028 = 15.4000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp028 = 231865.4434
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp028 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp028 = 5.4369
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp028 = 0.0000
# -- Starting eval on experience 29 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 65.37it/s]
# > Eval on experience 29 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp029 = 15.2000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp029 = 231866.3086
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp029 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp029 = 3.7139
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp029 = 0.0000
# -- Starting eval on experience 30 (Task 0) from test stream --
# 0it [00:00, ?it/s]after squeeze : torch.Size([10, 256])
# 100%|██████████| 1/1 [00:00<00:00, 69.79it/s]
# > Eval on experience 30 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp030 = 16.5000
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp030 = 231867.1738
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp030 = 0.0321
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp030 = 1.0000
# -- >> End of eval phase << --
# 	DiskUsage_Stream/eval_phase/test_stream/Task000 = 231867.1738
# 	Loss_Stream/eval_phase/test_stream/Task000 = 9.4629
# 	StreamForgetting/eval_phase/test_stream = 0.9967
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0323

# %%
d = eval_plugin.get_last_metrics()

# %%
model4.classifier.classifier
# Out:
# Linear(in_features=256, out_features=31, bias=True)

# %%
model_incs
# Out:
# [Linear(in_features=256, out_features=1, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True),
#  Linear(in_features=256, out_features=31, bias=True)]

# %%
classes_exp
# Out:
# [[27],
#  [22],
#  [29],
#  [8],
#  [12],
#  [13],
#  [5],
#  [16],
#  [21],
#  [4],
#  [19],
#  [9],
#  [23],
#  [17],
#  [26],
#  [2],
#  [1],
#  [25],
#  [28],
#  [6],
#  [20],
#  [11],
#  [18],
#  [0],
#  [7],
#  [10],
#  [3],
#  [30],
#  [24],
#  [15],
#  [14]]
